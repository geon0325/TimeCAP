# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt
from openai import OpenAI
from datetime import datetime

# %%
with open('time_series.pkl', 'rb') as f:
    data = pkl.load(f)

# %%
with open('indices.pkl', 'rb') as f:
    indices = pkl.load(f)

# %%
data_size = data.shape[0]
window_size = 20
print(data_size, data.shape, window_size)
# Out:
# 1258 (1258, 10) 20

# %%
system_prompt = f"Your job is to act as a professional finance analyst. You will write a high-quality report that is informative and helps in understanding the current financial situation."
print(system_prompt)
# Out:
# Your job is to act as a professional finance analyst. You will write a high-quality report that is informative and helps in understanding the current financial situation.

# %%
client = OpenAI(api_key='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')

# %%
for i in indices[:991]:
    if os.path.exists(f'chatgpt_response_summary/{i}.txt'):
        print('Exists')
        #continue
    
    data_window = data[i:i+window_size]
    print(data[i][0])
    
    s_p_500 = '|'.join([f"{x:.2f}" for x in data_window[:,1]])
    vix = '|'.join([f"{x:.2f}" for x in data_window[:,2]])
    nikkei_225 = '|'.join([f"{x:.2f}" for x in data_window[:,3]])
    ftse_100 = '|'.join([f"{x:.2f}" for x in data_window[:,4]])
    gold_futures = '|'.join([f"{x:.2f}" for x in data_window[:,5]])
    crude_oil_futures = '|'.join([f"{x:.2f}" for x in data_window[:,6]])
    eur_usd = '|'.join([f"{x:.2f}" for x in data_window[:,7]])
    usd_jpy = '|'.join([f"{x:.2f}" for x in data_window[:,8]])
    usd_cny = '|'.join([f"{x:.2f}" for x in data_window[:,9]])
    
    user_prompt = f"Your task is to analyze key financial indicators over the last {window_size} market days."
    user_prompt += f"\n\nReview the time-series data provided for the last {window_size} market days. "
    user_prompt += f"Each time-series consists of daily values separated by a \'|\' token for the following indicators:\n"
    user_prompt += f"- S&P 500: {s_p_500}\n- VIX (Volatility Index): {vix}\n- Nikkei 225: {nikkei_225}\n- FTSE 100: {ftse_100}\n- Gold Futures: {gold_futures}\n- Crude Oil Futures: {crude_oil_futures}\n- Exchange rate for EUR/USD: {eur_usd}\n- Exchange rate for USD/JYP: {usd_jpy}\n- Exchange rate for USD/CNY: {usd_cny}\n\n"
    user_prompt += f"Based on this time-series data, write a concise report that provides insights crucial for understanding the current financial situation. "
    user_prompt += f"Your report should be limited to five sentences, yet comprehensive, highlighting key trends and considering their potential impact on the market."
    user_prompt += f"Do not write numerical values while writing the report."
    #user_prompt += "Do not write redundant information."
    break
    
    response = client.chat.completions.create(
        model="gpt-4-1106-preview",
        messages=[
        {
          "role": "system",
          "content": system_prompt
        },
        {
          "role": "user",
          "content": user_prompt
        }
        ],
        temperature=0.7,
        max_tokens=2048,
        top_p=1
    )

    text = response.choices[0].message.content
    print(text, '\n')

    with open(f'chatgpt_response_summary/{i}.txt', 'w') as f:
        f.write(text)
# Out:
# Exists
# 2019-01-02 00:00:00

# %%
text.replace('\n\n', ' ')
# Out:
# 'The S&P 500 has shown an overall upward trend over the last 20 market days, indicating a potentially bullish market sentiment, despite some volatility. The VIX, or Volatility Index, has decreased from 23.22 to 17.66, suggesting that investor fear and market risk perception have diminished, which could be a positive sign for the stability of the S&P 500. International markets like the Nikkei 225 and FTSE 100 have experienced fluctuations, but their latest trend also points to a recovery, which might support global investor confidence and contribute positively to US markets. Commodity prices for Gold and Crude Oil Futures have both increased, with Gold indicating a possible hedge against market uncertainty, and the rise in Oil prices could signal an expectation of economic growth. Lastly, the exchange rates of EUR/USD and USD/CNY show a slight depreciation of the dollar, which could potentially boost the earnings of S&P 500 companies with international exposure, while the USD/JPY has 
# ...

# %%
user_prompt = "You are tasked with analyzing key financial indicators to assess the current market conditions and provide insights for predicting future trends for the S&P 500 index.\n\nReview the time-series data provided for the last 20 market days. Each time-series consists of daily values separated by a \'|\' token for the following indicators:\n- S&P 500: {s_p_500}\n- VIX (Volatility Index): {vix}\n- Nikkei 225: {nikkei_225}\n- FTSE 100: {ftse_100}\n- Gold Futures: {gold_futures}\n- Crude Oil Futures: {crude_oil_futures}\n- Exchange rate for EUR/USD: {eur_usd}\n- Exchange rate for USD/JYP: {usd_jpy}\n- Exchange rate for USD/CNY: {usd_cny}\n\nBased on this data, write a concise report that describes the financial situation and provides insights crucial for understanding current market dynamics and forecasting future movements of the S&P 500. Your report should be limited to five sentences, yet comprehensive, highlighting key trends and considering their potential impact on the S&P 500. This summary will aid in forecasting potential shifts in the index, proving useful for investors and analysts."

# %%
user_prompt
# Out:
# "You are tasked with analyzing key financial indicators to assess the current market conditions and provide insights for predicting future trends for the S&P 500 index.\n\nReview the time-series data provided for the last 20 market days. Each time-series consists of daily values separated by a '|' token for the following indicators:\n- S&P 500: {s_p_500}\n- VIX (Volatility Index): {vix}\n- Nikkei 225: {nikkei_225}\n- FTSE 100: {ftse_100}\n- Gold Futures: {gold_futures}\n- Crude Oil Futures: {crude_oil_futures}\n- Exchange rate for EUR/USD: {eur_usd}\n- Exchange rate for USD/JYP: {usd_jpy}\n- Exchange rate for USD/CNY: {usd_cny}\n\nBased on this data, write a concise report that describes the financial situation and provides insights crucial for understanding current market dynamics and forecasting future movements of the S&P 500. Your report should be limited to five sentences, yet comprehensive, highlighting key trends and considering their potential impact on the S&P 500. This summ
# ...

# %%
data.shape
# Out:
# (1258, 9)

# %%
print(system_prompt)
# Out:
# Your job is to act as a professional finance analyst. You will write a high-quality report that is informative and helps in understanding the current financial situation.

# %%
print(user_prompt)
# Out:
# Your task is to analyze key financial indicators over the last 20 market days.
#
# Review the time-series data provided for the last 20 market days. Each time-series consists of daily values separated by a '|' token for the following indicators:
# - S&P 500: 2510.03|2447.89|2531.94|2549.69|2574.41|2584.96|2596.64|2596.26|2582.61|2610.30|2616.10|2635.96|2670.71|2632.90|2638.70|2642.33|2664.76|2643.85|2640.00|2681.05
# - VIX (Volatility Index): 23.22|25.45|21.38|21.40|20.47|19.98|19.50|18.19|19.07|18.60|19.04|18.06|17.80|20.80|19.52|18.89|17.42|18.87|19.13|17.66
# - Nikkei 225: 20014.77|20014.77|19561.96|20038.97|20204.04|20427.06|20163.80|20359.70|20359.70|20555.29|20442.75|20402.27|20666.07|20622.91|20593.72|20574.63|20773.56|20649.00|20664.64|20556.54
# - FTSE 100: 6734.20|6692.70|6837.40|6810.90|6861.60|6906.60|6942.90|6918.20|6855.00|6895.00|6862.70|6834.90|6968.30|6901.40|6842.90|6819.00|6809.20|6747.10|6833.90|6941.60
# ...

# %%
for i in indices[200:201]:
    with open(f'chatgpt_response_summary/{i}.txt', 'r') as f:
        report = f.read()
        print(report)
    print()
    
    data_window = data[i:i+window_size]
    
    s_p_500 = data_window[:,1]
    vix = data_window[:,2]
    nikkei_225 = data_window[:,3]
    ftse_100 = data_window[:,4]
    gold_futures = data_window[:,5]
    crude_oil_futures = data_window[:,6] 
    eur_usd = data_window[:,7]
    usd_jpy = data_window[:,8]
    usd_cny = data_window[:,9]
# Out:
# Over the last 20 market days, the S&P 500 has shown a steady upward trend, increasing from 2997.95 to 3094.04, indicating a positive sentiment among investors and a potential growth period for the US markets. The VIX, commonly known as the "fear index," has hovered around the low-to-mid teens, with a slight increase from 13.79 to 13.00, suggesting that market volatility has remained relatively stable and investor confidence is steady. International markets have seen mixed movements, with Japan's Nikkei 225 experiencing a moderate increase, closing higher at 23319.87 from an opening of 22451.86, while the UK's FTSE 100 displayed slight fluctuations but ultimately dipped from 7182.30 to 7351.20, which could reflect ongoing uncertainties in the region, possibly related to Brexit developments.
#
# ...

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('S&P 500', fontsize=16)
ax.plot(np.arange(1, 21, 1), s_p_500, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/sp500.pdf')

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('VIX', fontsize=16)
ax.plot(np.arange(1, 21, 1), vix, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/vix.pdf')

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('NIKKEI 225', fontsize=16)
ax.plot(np.arange(1, 21, 1), nikkei_225, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/nikkei.pdf')

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('FTSE 100', fontsize=16)
ax.plot(np.arange(1, 21, 1), ftse_100, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/ftse.pdf')

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('Crude Oil\nFutures', fontsize=16)
ax.plot(np.arange(1, 21, 1), crude_oil_futures, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/crude_oil_futures.pdf')

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('Gold Futures', fontsize=16)
ax.plot(np.arange(1, 21, 1), gold_futures, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/gold_futures.pdf')

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('EUR/USD', fontsize=16)
ax.plot(np.arange(1, 21, 1), eur_usd, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/eur_usd.pdf')

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('USD/JYP', fontsize=16)
ax.plot(np.arange(1, 21, 1), usd_jpy, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/usd_jpy.pdf')

# %%
fig, ax = plt.subplots(figsize=(5, 2.4))

ax.tick_params(axis='x', labelsize=16)
ax.set_xlabel('Time (days)', fontsize=16)

ax.set_ylabel('USD/CNY', fontsize=16)
ax.plot(np.arange(1, 21, 1), usd_cny, 'o-', linewidth=2, markersize=8, color='tab:blue', label='Humidity')

#ax.set_yticks([50, 60, 70, 80, 90])
ax.tick_params(axis='y', labelsize=16)

ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)

# Removing top and right lines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.savefig('figures/usd_cny.pdf')
